# %% [markdown]
# # Emotion Detection

# %% [markdown]
# **importing Libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version: ",tf.__version__)
# Out:
# Tensorflow version:  2.14.0

# %% [markdown]
# **Exploring Dataset**

# %%
images=glob("train/**/**")
for i in range(9):
    image=random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(661+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing Data for Training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                    target_size = (img_size,img_size),
                                                    color_mode = "grayscale",
                                                    batch_size = batch_size,
                                                    class_mode = "categorical",
                                                    shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(conv_1,64,(5,5))
    conv_3 = Convolution(conv_2,128,(3,3))

    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten,256)

    output  = Dense(7, activation="softmax")(dense_1)
    model  =  Model(inputs=[inputs],outputs = [output])
    
    model.compile(loss=['categorical_crossentropy'] , optimizer = 'adam' , metrics =["accuracy"])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_1 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d (Conv2D)             (None, 48, 48, 32)        320
#
#  batch_normalization (Batch  (None, 48, 48, 32)        128
#  Normalization)
#
#  activation (Activation)     (None, 48, 48, 32)        0
#
#  max_pooling2d (MaxPooling2  (None, 24, 24, 32)        0
#  D)
#
#  dropout (Dropout)           (None, 24, 24, 32)        0
#
#  conv2d_1 (Conv2D)           (None, 24, 24, 64)        51264
#
#  batch_normalization_1 (Bat  (None, 24, 24, 64)        256
#  chNormalization)
#
#  activation_1 (Activation)   (None, 24, 24, 64)        0
#
#  max_pooling2d_1 (MaxPoolin  (None, 12, 12, 64)        0
#  g2D)
#
#  dropout_1 (Dropout)         (None, 12, 12, 64)        0
#
#  conv2d_2 (Conv2D)           (None, 12, 12, 128)       73856
#
#  batch_normalization_2 (Bat  (None, 12, 12, 128)       512
#  chNormalization)
#
#  activation_2 (Activation)   (None, 12, 12, 128)       0
#
#  max_pooling2d_2 (MaxPoolin  (None, 6, 6, 128)         0
#  g2D)
#
#  dropout_2 (Dropout)         (None, 6, 6, 128)         0
#
#  flatten (Flatten)           (None, 4608)              0
#
#  dense (Dense)               (None, 256)               1179904
#
#  batch_normalization_3 (Bat  (None, 256)               1024
#  chNormalization)
#
#  activation_3 (Activation)   (None, 256)               0
#
#  dropout_3 (Dropout)         (None, 256)               0
#
#  dense_1 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1309063 (4.99 MB)
# Trainable params: 1308103 (4.99 MB)
# Non-trainable params: 960 (3.75 KB)
# _________________________________________________________________

# %% [markdown]
# **Initializing the Model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# # Training the Model

# %% [markdown]
# **The next cell takes time to complete**

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6817 - accuracy: 0.3610
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 549s 1s/step - loss: 1.6817 - accuracy: 0.3610 - val_loss: 1.4794 - val_accuracy: 0.4244
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3893 - accuracy: 0.4693
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 183s 408ms/step - loss: 1.3893 - accuracy: 0.4693 - val_loss: 1.4262 - val_accuracy: 0.4713
# Epoch 3/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2754 - accuracy: 0.5144
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 182s 407ms/step - loss: 1.2754 - accuracy: 0.5144 - val_loss: 1.4106 - val_accuracy: 0.4717
# Epoch 4/15
# 448/448 [==============================] - ETA: 0s - loss: 1.2024 - accuracy: 0.5438
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 188s 420ms/step - loss: 1.2024 - accuracy: 0.5438 - val_loss: 1.2304 - val_accuracy: 0.5324
# Epoch 5/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1491 - accuracy: 0.5658
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 180s 401ms/step - loss: 1.1491 - accuracy: 0.5658 - val_loss: 1.4471 - val_accuracy: 0.4688
# Epoch 6/15
# 448/448 [==============================] - ETA: 0s - loss: 1.1075 - accuracy: 0.5802
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 191s 427ms/step - loss: 1.1075 - accuracy: 0.5802 - val_loss: 1.1997 - val_accuracy: 0.5399
# Epoch 7/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0658 - accuracy: 0.5988
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 185s 412ms/step - loss: 1.0658 - accuracy: 0.5988 - val_loss: 1.2964 - val_accuracy: 0.5199
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0193 - accuracy: 0.6152
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 228s 508ms/step - loss: 1.0193 - accuracy: 0.6152 - val_loss: 1.1031 - val_accuracy: 0.5857
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9786 - accuracy: 0.6342
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 184s 410ms/step - loss: 0.9786 - accuracy: 0.6342 - val_loss: 1.0789 - val_accuracy: 0.5884
# Epoch 10/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9457 - accuracy: 0.6489
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 186s 415ms/step - loss: 0.9457 - accuracy: 0.6489 - val_loss: 1.1052 - val_accuracy: 0.5854
# Epoch 11/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9077 - accuracy: 0.6622
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 183s 408ms/step - loss: 0.9077 - accuracy: 0.6622 - val_loss: 1.1055 - val_accuracy: 0.5914
# Epoch 12/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8655 - accuracy: 0.6776
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 215s 480ms/step - loss: 0.8655 - accuracy: 0.6776 - val_loss: 1.0980 - val_accuracy: 0.6028
# Epoch 13/15
# 448/448 [==============================] - ETA: 0s - loss: 0.8338 - accuracy: 0.6922
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 212s 473ms/step - loss: 0.8338 - accuracy: 0.6922 - val_loss: 1.0907 - val_accuracy: 0.5958
# Epoch 14/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7978 - accuracy: 0.7038
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 166s 369ms/step - loss: 0.7978 - accuracy: 0.7038 - val_loss: 1.2611 - val_accuracy: 0.5412
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7637 - accuracy: 0.7180
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 158s 352ms/step - loss: 0.7637 - accuracy: 0.7180 - val_loss: 1.2099 - val_accuracy: 0.5756

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 12s 102ms/step - loss: 1.2098 - accuracy: 0.5755
# [1.20975661277771, 0.5755084753036499]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc='upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right=0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
